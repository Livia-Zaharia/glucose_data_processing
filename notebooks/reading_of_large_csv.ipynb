# %%
import polars as pl
from pathlib import Path

# Configure Polars to show more rows and columns
pl.Config.set_tbl_rows(-1)  # Show all rows
pl.Config.set_tbl_cols(-1)  # Show all columns
pl.Config.set_tbl_width_chars(1000)  # Increase table width
pl.Config.set_fmt_str_lengths(1000)  # Show longer string values without truncation
# Out:
# polars.config.Config

# %%
df = pl.scan_csv("D:\\01_1_LIVIA\\LIVIA_DOCS\\CODING\\sources\\milestone3\\glucose_data_processing\\OUTPUT\\loop_ml_ready.csv")
df.head(5000).sink_csv("D:\\01_1_LIVIA\\LIVIA_DOCS\\CODING\\sources\\milestone3\\glucose_data_processing\\OUTPUT\\cut+loop_ml_ready.csv")
